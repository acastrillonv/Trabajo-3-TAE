# %%
# Primero debemos importar la librería pandas
import pandas as pd
import numpy as np
# A continuación, se cargan los datos
data=pd.read_csv('incidentes_viales.csv',sep=';')
# Out:
# C:\Users\Edwar\AppData\Local\Temp\ipykernel_9236\206547807.py:5: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('incidentes_viales.csv',sep=';')

# %%
data
# Out:
#          AÑO  CBML CLASE_ACCIDENTE      DIRECCION       DIRECCION ENCASILLADA  \
# 0       2015  1013  Caida Ocupante    CR 46 CL 43    CR  046   043  000 00000
# 1       2015  1020          Choque  CR 43 A CL 29  CR  043 A   029  000 00000
# 2       2015  0205            Otro    CR 46 CL 37    CR  046   037  000 00000
# 3       2015  0101       Atropello   CR 34 CL 112    CR  034   112  000 00000
# 4       2015  1504          Choque    CR 50 CL 14    CR  050   014  000 00000
# ...      ...   ...             ...            ...                         ...
# 270760  2020  1004  Caida Ocupante    CR 62 CL 59    CR  062   059  000 00000
# 270761  2020  1115            Otro    CL 50 CR 74    CL  050   074  000 00000
# 270762  2020   515          Choque    CL 80 CR 65    CL  080   065  000 00000
# 270763  2020   207       Atropello   CL 104 CR 45    CL  104   045  000 00000
# 270764  2020   303       Atropello    CR 44 CL 79    CR  044   079  000 00000
#
# ...

# %%
data[data["GRAVEDAD_ACCIDENTE"]=="Cerro Nutibara"]
# Out:
#                                                       AÑO CBML  \
# 183406  2018;"";Atropello;CR 63 entre CL 30 y 31 A;CR ...    "
#
#        CLASE_ACCIDENTE            DIRECCION     DIRECCION ENCASILLADA  \
# 183406      A000854229  20/10/2018 18:20:00  2018-10-20T23:20:00.000Z
#
#              DISEÑO EXPEDIENTE FECHA_ACCIDENTE FECHA_ACCIDENTES  \
# 183406  Con muertos         10           28434          Sin Inf
#
#        GRAVEDAD_ACCIDENTE    MES                      NRO_RADICADO  \
# 183406     Cerro Nutibara  Belén  [-75.5759511084", 6.23383430995]
#
#                 NUMCOMUNA              BARRIO COMUNA LOCATION   X  Y,,
# 183406  834155.2581849237  1181332.0243087297    NaN      NaN NaN  NaN

# %%
data["AÑO"].value_counts()
# Out:
# 2016                                                                                                                                                                                                   43293
# 2017                                                                                                                                                                                                   42489
# 2015                                                                                                                                                                                                   42431
# 2018                                                                                                                                                                                                   40005
# ...

# %%
dataR = data[(data["AÑO"]!= "2016") & (data["AÑO"]!= "2017") & (data["AÑO"]!= "2018") & (data["AÑO"]!= "2019") & (data["AÑO"]!= "2015") & (data["AÑO"]!= "2020") & (data["AÑO"]!= "2014") & (data["AÑO"]!= "2019\\r")]

# %%
dataR
# Out:
#                                                       AÑO    CBML  \
# 24      2015;"";Choque;TV 39 B CL 4;0;Tramo de via;A00...  820000
# 26      2015;"";Choque;CR 80 CL 15;0;Tramo de via;A000...  820000
# 36      2015;"";Choque;CL 647 CR 62;0;Tramo de via;A00...  820000
# 53      2015;"";Otro;CR 93 CL 97 D;0;Tramo de via;A000...  820000
# 69      2015;"";Choque;CL 33 A NorOrienteCR 64;0;Tramo...  820000
# ...                                                   ...     ...
# 269156  2020;"";Choque;CR 28 CL 77 B;CR  028   077 B  ...  820000
# 269194  2020;"";Choque;CR 999 CL 4;CR  999   004  000 ...  820000
# 269215  2020;"";Choque;CL 110 CR 25;CL  110   025  000...  820000
# 269223  2020;"";Choque;CR 12 A CL 57;CR  012 A   057  ...  820000
# 269270  2020;"";Choque;CR 4 Sur CL 43 A;CR  004  S 043...  820000
#
#        CLASE_ACCIDENTE DIRECCION DIRECCION ENCASILLADA DISEÑO EXPEDIENTE  \
# 24            1180000,       NaN                   NaN    NaN        NaN
# ...

# %%
dataR["AÑO"].value_counts()
# Out:
# 2017;0206;Choque;CR 52 CL 107;CR  052   107  000 00000;"";A000673223;25/12/2017 10:00:00;2017-12-25T15:00:00.000Z;Con muertos;12;62196;02;Andalucía;Santa Cruz;[-75.5574464031, 6.29966255324]                                                                                    3
# 2017;"";Choque;DG 75 B entre CL 7 y 9;DG  075 B   07,"  009 00000                                                                                                                                                                                                                 2
# 2015;80003360020;Choque;CR 63 CL 50 C Sur 09;CR  063  S 050 C  009 00000;"";A000177042;13/05/2015 18:31:00;2015-05-13T23:31:00.000Z;Con muertos;5;050016000206201523690;80;Cabecera San Antonio de Prado;Corregimiento de San Antonio de Prado;[-75.6448608945, 6.17708308094]    2
# ...

# %%
dataR.isnull().sum()
# Out:
# AÑO                          0
# CBML                         0
# CLASE_ACCIDENTE              0
# DIRECCION                20014
# DIRECCION ENCASILLADA    20014
# DISEÑO                   20014
# EXPEDIENTE               20014
# FECHA_ACCIDENTE          20014
# FECHA_ACCIDENTES         20014
# GRAVEDAD_ACCIDENTE       20014
# MES                      20014
# NRO_RADICADO             20014
# NUMCOMUNA                20014
# BARRIO                   20014
# COMUNA                   20025
# LOCATION                 20027
# X                        20027
# Y,,                      20027
# dtype: int64
